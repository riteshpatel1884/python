# %%
a = "Ritesh Patel"
print(a[::])  # It will print the string as it is. 

print(a[5::1])  /# If no vlaue is written so it means till the last of string
# Out:
# Ritesh Patel
# h Patel

# %%
age = int(input("hello what is your age"))

print(age)
# Out:
# 21

# %%
name = "Ritesh"
age = "21"

print(f"my name is {name} and my age is {age}")
# Out:
# my name is Ritesh and my age is 21
