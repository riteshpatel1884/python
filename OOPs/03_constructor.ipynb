# %%
class Factory:
    def __init__ (self, material, zips, pocket):   # initilization function
        self.material = material
        self.zips = zips
        self.pocket = pocket


obj = Factory("Leather", 3,2)

print(obj.material)
# object obj ki location self pe jayegi.m
# Out:
# Leather
