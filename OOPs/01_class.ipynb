# %%
class Factory:
    name = "Ritesh" # attribute
    def hello(): # method
        print("Hi")
    print("Print statement")
# Out:
# Print statement

# %%
class Factory:
    name = "Ritesh" 
    def hello():
        print("Hi")

print(Factory.name)
print(Factory.hello())
# Out:
# Ritesh
# Hi
# None
