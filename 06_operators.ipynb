# %% [markdown]
# Aeithmetic Operators

# %%
a = 5
b = 32

print(a + b)
print(b - a)
print(a * b)
print(b//a)
print(b/a)
print(5**10)
print(32%5)
print(12+4/2)
# Out:
# 37
# 27
# 160
# 6
# 6.4
# 9765625
# 2
# 14.0

# %% [markdown]
# Assignment Operators

# %%
a = 23
print(a)
# Out:
# 23

# %% [markdown]
# Compound Assignment Operator

# %%
a = 20
a = a + 20  # 40
a = a + 40  # 80
print(a)

# It is called value reassignment
# OR

b = 20
b+= 20  
b+= 40

print(b)
# Out:
# 80
# 80

# %% [markdown]
# Comparison Operator
# >
# <
# >=
# <=
# ==
# !=

# %% [markdown]
# Logical Operator
# - and
# - or
# - not: Reverse the boolean values

# %%
print(12==12)
# Out:
# True

# %%
print(not 12==12)  # It will reverse the result of 12 == 12
# Out:
# False
