# %%
a = 12
a = str(a)
print(a)
# Out:
# 12

# %%
a = "123"
print(int(a))
# Out:
# 123

# %% [markdown]
# There are 7 falsy values
# - 0
# - 0.0
# - false
# - ""
# - []
# - ()
# - {}

# %%
print(bool(0))
# Out:
# False

# %%
print(bool([]))
# Out:
# False
