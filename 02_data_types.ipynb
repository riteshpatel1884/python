# %%
a = -34 
b = 56.8
c = 12/3
v = 34j

print(type(a))
print(type(b))
print(type(c))
print(type(v))


str = '1231243235 dsagaiogiaeb !@#$%^&*'
print(type(str))

b = True
t = False
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>
