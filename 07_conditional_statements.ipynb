# %% [markdown]
# If else

# %%
a =11
if a>10:
    print(a)
# Out:
# 11

# %%
a =1
if a>10:
    print(a)
else:
    print("Smaller")
# Out:
# Smaller

# %% [markdown]
# If- elif ladder

# %%
a = 6
if a==1:
    print("Hi")
elif a == 2:
    print("bye")
elif a==3:
    print("okay")
else: 
    print("NOT FOUND")
# Out:
# NOT FOUND
